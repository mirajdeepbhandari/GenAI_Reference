# %% [markdown]
# # C Transformers with GGUF AND GGML (BOTH SUPPORTED)

# %%
# !pip install ctransformers ctransformers[cuda]

# %% [markdown]
# ```
# Check ctransformers supports or not the model u r using
# ```

# %%
from ctransformers import AutoModelForCausalLM

llm = AutoModelForCausalLM.from_pretrained("TheBloke/Llama-2-7B-GGUF",
                                           model_file="llama-2-7b.Q2_K.gguf",
                                           max_new_tokens=50 ,
                                           gpu_layers=100) # we dont use -1 here for gpu for all layers
# Out:
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# llama-2-7b.Q2_K.gguf:   0%|          | 0.00/2.83G [00:00<?, ?B/s]

# %%
llm("write a paragraph about nepal")
# Out:
# '\n sierpirinhas.com.br/2018/09/05/write-a-paragraph-about-nepal-essay-paragraph/'

# %% [markdown]
# # C transformers with langchain

# %%
# !pip install langchain
# !pip install ctransformers ctransformers[cuda]

# %%
from langchain_community.llms import CTransformers

# %%
config = {'max_new_tokens': 256, 'repetition_penalty': 1.1, 'gpu_layers':100}
# for more parameters in config go= https://github.com/marella/ctransformers
llm = CTransformers(model='TheBloke/Llama-2-7B-Chat-GGML', model_file='llama-2-7b-chat.ggmlv3.q5_1.bin',config=config)
# Out:
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
llm.invoke("i want to live in")
# Out:
# ' a world where everyone has access to clean water, nutritious food, and adequate shelter. i want to live in a world where people are not discriminated against because of their race, religion, or gender.\n– Greta Thunberg, Environmental Activist\nThis quote from Greta Thunberg highlights the importance of basic human rights such as access to clean water, nutritious food, and adequate shelter. It also emphasizes the need for equality and non-discrimination based on race, religion, or gender. These are fundamental rights that are essential for a fair and just society.\nAccess to clean water is a basic human right, yet millions of people around the world do not have access to it. This is particularly true in developing countries where poverty and conflict have led to a lack of infrastructure and resources. Ensuring that everyone has access to clean water is essential for maintaining good health and preventing waterborne diseases.\nSimilarly, nutritious food is crucial for maintaining good health and well-being. Unfortunately, many people around the world suffer from hunger and malnutrition due to poverty, conflict, and climate change. Ensuring'
